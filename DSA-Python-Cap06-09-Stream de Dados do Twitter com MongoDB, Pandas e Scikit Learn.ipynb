# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ## Download: http://github.com/dsacademybr

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())

# %% [markdown]
# ## Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %% [markdown]
# ## Preparando a Conexão com o Twitter

# %%
# Instala o pacote tweepy
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-3.9.0-py2.py3-none-any.whl (30 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\homeoffice\anaconda3\lib\site-packages (from tweepy) (1.14.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\homeoffice\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\homeoffice\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\homeoffice\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\homeoffice\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\homeoffice\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\homeoffice\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.9.0

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# Veja no manual em pdf como criar sua API no Twitter e configure as suas chaves abaixo.

# %%
# Adicione aqui sua Consumer Key
consumer_key = "W1JmKMmnrtHIClA509ld4oQvv"

# %%
# Adicione aqui sua Consumer Secret 
consumer_secret ="lnCXe6fx4TalB3bMCkzHdmwU9CX150D6ck6YLs7rzOejxCShII"

# %%
# Adicione aqui seu Access Token
access_token = "1335715319927726083-VKAqkQab5jZ2uGTpDkN5qVIrRfdFeh"

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = "3JseoYgzalWfTAiJBkMDLcmdSsMldUWzd6Fru0GnrDm0q"

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ## Preparando a Conexão com o MongoDB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Big Data', 'Python', 'Data Mining', 'Data Science']

# %% [markdown]
# ## Coletando os Tweets

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Sun Dec 06 23:29:14 +0000 2020', 'id_str': '1335728035245432834', 'text': 'github 上で最も多く使われているのは javascript。次点で python。typescript の伸びがすごい。 / “The State of the Octoverse | The State of the Oc… https://t.co/YyWoVqno8R', '_id': ObjectId('5fcd6950494e7827cd00c4ae')}
# {'created_at': 'Sun Dec 06 23:29:20 +0000 2020', 'id_str': '1335728056925872128', 'text': 'RT @hnishi2509: github 上で最も多く使われているのは javascript。次点で python。typescript の伸びがすごい。 / “The State of the Octoverse | The State of the Octoverse…', '_id': ObjectId('5fcd6955494e7827cd00c4af')}
# {'created_at': 'Sun Dec 06 23:29:23 +0000 2020', 'id_str': '1335728073023520768', 'text': "Big changes to QRIScloud are afoot, with ageing hardware replaced with new tech. It'll be bigger/better + more serv… https://t.co/yooVZnNmMK", '_id': ObjectId('5fcd6959494e7827cd00c4b0')}
# {'created_at': 'Sun Dec 06 23:29:27 +0000 2020', 'id_str': '1335728089326870529', 'text': 'Historically the racialised disproportionate effects have been covered up. Hope you and your baby stay safe! 😘', '_id': ObjectId('5fcd695d494e7827cd00c4b1')}
# {'created_at': 'Sun Dec 06 23:29:29 +0000 2020', 'id_str': '1335728098483036161', 'text': 'RT @StackCodeReview: Hackerrank: Count the number of palindromes in a given string https://t.co/3MX9I3Hd1L #python', '_id': ObjectId('5fcd695f494e7827cd00c4b2')}
# {'created_at': 'Sun Dec 06 23:29:34 +0000 2020', 'id_str': '1335728119232176131', 'text': 'RT @MeowTPN: Historically the racialised disproportionate effects have been covered up. Hope you and your baby stay safe! 😘 https://t.co/90…', '_id': ObjectId('5fcd6964494e7827cd00c4b3')}
# {'created_at': 'Sun Dec 06 23:29:46 +0000 2020', 'id_str': '1335728166640431107', 'text': 'RT @CroatiaC: Top story: Big data trends: Artificial intelligence leads Twitter mentions in November 2020 https://t.co/e7CDCoxnRU, see more…', '_id': ObjectId('5fcd696f494e7827cd00c4b4')}
# {'created_at': 'Sun Dec 06 23:29:46 +0000 2020', 'id_str': '1335728168544727046', 'text': '@lipsaraiva @pizzaiolom @PizzaiolomX @D1oRod Na realidade, por ser python fica ainda mais fácil de encontrar. Vem D… https://t.co/t5vnvVzyKP', '_id': ObjectId('5fcd696f494e7827cd00c4b5')}
# {'created_at': 'Sun Dec 06 23:29:50 +0000 2020', 'id_str': '1335728182956265472', 'text': 'RT @JanJekielek: Communist #China "used artificial intelligence &amp; big data to identify Americans likely to participate in Antifa &amp; Black Li…', '_id': ObjectId('5fcd6973494e7827cd00c4b6')}
# {'created_at': 'Sun Dec 06 23:29:51 +0000 2020', 'id_str': '1335728186731139073', 'text': 'RT @carlcarrie: TsEuler - Holoviews Panel based dashboarding tool for Jupyter/ Python exploration of time-series\n\nhttps://t.co/No5bYPo7T9 h…', '_id': ObjectId('5fcd6974494e7827cd00c4b7')}
# {'created_at': 'Sun Dec 06 23:29:53 +0000 2020', 'id_str': '1335728196919037952', 'text': 'RT @karynbaum: empathy=weakness\n"freedom"=right to harm others https://t.co/dbBZsyiWlW', '_id': ObjectId('5fcd6976494e7827cd00c4b8')}
# {'created_at': 'Sun Dec 06 23:29:54 +0000 2020', 'id_str': '1335728201688035330', 'text': 'RT @PGtzsche1: Covid-19 vaccines: Science by press release, on the basis of interim or ad hoc analyses, no access to the data. Remember the…', '_id': ObjectId('5fcd6977494e7827cd00c4b9')}
# {'created_at': 'Sun Dec 06 23:29:55 +0000 2020', 'id_str': '1335728204204498944', 'text': 'RT @IWasHrren: Pennsylvania Dems predict\nAT LEAST 1 million mail in ballots SHOULD BE REJECTED\n\nWith 10X MAIL IN BALLOTS\nMOSTLY DEMOCRAT\nAs…', '_id': ObjectId('5fcd6978494e7827cd00c4ba')}
# {'created_at': 'Sun Dec 06 23:30:00 +0000 2020', 'id_str': '1335728225432055808', 'text': "#InPics | December 4, 1971: How Indian Navy's Operation Trident led to the destruction of Karachi, followed by Oper… https://t.co/RzpMStnawB", '_id': ObjectId('5fcd697d494e7827cd00c4bb')}
# {'created_at': 'Sun Dec 06 23:30:00 +0000 2020', 'id_str': '1335728226891653121', 'text': '🐍📰 How to Run Your Python Scripts \n\nThis step-by-step tutorial will guide you through a series of ways to run Pytho… https://t.co/iSAHi7Ozgs', '_id': ObjectId('5fcd697d494e7827cd00c4bc')}
# {'created_at': 'Sun Dec 06 23:30:00 +0000 2020', 'id_str': '1335728228523110400', 'text': 'Kubernetes:What You Need To Know \nhttps://t.co/0GLoI8xhql #python #ansible #devops #linux #sdn #iot… https://t.co/7NunpRHfeM', '_id': ObjectId('5fcd697e494e7827cd00c4bd')}
# {'created_at': 'Sun Dec 06 23:30:02 +0000 2020', 'id_str': '1335728234407677954', 'text': 'buildreeを使えば開発に専念できます\n https://t.co/ucQNXnOUmk\n#buildree #php #Laravel #fuelphp #フレームワーク #apache #nginx #エンジニア… https://t.co/hnOAFLNgFs', '_id': ObjectId('5fcd697f494e7827cd00c4be')}
# {'created_at': 'Sun Dec 06 23:30:02 +0000 2020', 'id_str': '1335728236437921794', 'text': 'The first purchase on Amazon was by a Bay Area programmer in 1995. It was “Fluid Concepts And...… https://t.co/JCkmsGTKv5', '_id': ObjectId('5fcd6980494e7827cd00c4bf')}
# {'created_at': 'Sun Dec 06 23:30:03 +0000 2020', 'id_str': '1335728240531542016', 'text': "RT @gazcon: @LBC @NIAbbot I'd need to be persuaded that a) Covid poses me a significant threat and b) the vaccine poses me no threat.\n\nRigh…", '_id': ObjectId('5fcd6981494e7827cd00c4c0')}
# {'created_at': 'Sun Dec 06 23:30:03 +0000 2020', 'id_str': '1335728241009700865', 'text': 'New upload: python-build 0.1.0-2 by Sergio Durigan Junior into unstable... https://t.co/foP51vMkgF', '_id': ObjectId('5fcd6981494e7827cd00c4c1')}
# {'created_at': 'Sun Dec 06 23:30:06 +0000 2020', 'id_str': '1335728249708687360', 'text': "I have a premium subscription on @MeWe now, but I'm still trying to figure out how best to use the platform. Anyone… https://t.co/8wTUoIrK0K", '_id': ObjectId('5fcd6983494e7827cd00c4c2')}
# {'created_at': 'Sun Dec 06 23:30:06 +0000 2020', 'id_str': '1335728251457728514', 'text': 'RT @DetlefBurkhardt: My week 49 on Twitter: 67 tweets and 88 hashtags. Built in R with #rtweet #wordcloud2 #stringr #textclean #rstudio #gl…', '_id': ObjectId('5fcd6983494e7827cd00c4c3')}
# {'created_at': 'Sun Dec 06 23:30:07 +0000 2020', 'id_str': '1335728256071462919', 'text': 'RT @y__hayashi: buildreeを使えば開発に専念できます\n https://t.co/ucQNXnOUmk\n#buildree #php #Laravel #fuelphp #フレームワーク #apache #nginx #エンジニア #python #go…', '_id': ObjectId('5fcd6984494e7827cd00c4c4')}
# {'created_at': 'Sun Dec 06 23:30:08 +0000 2020', 'id_str': '1335728259317710850', 'text': 'I can’t add anything valuable to this.', '_id': ObjectId('5fcd6985494e7827cd00c4c5')}
# {'created_at': 'Sun Dec 06 23:30:08 +0000 2020', 'id_str': '1335728259573551104', 'text': 'RT @GavLaaaaaaaa: The first purchase on Amazon was by a Bay Area programmer in 1995. It was “Fluid Concepts And... https://t.co/fQEYgzXlcV…', '_id': ObjectId('5fcd6985494e7827cd00c4c6')}
# {'created_at': 'Sun Dec 06 23:30:10 +0000 2020', 'id_str': '1335728266649481216', 'text': 'RT @karlbooklover: Los datos públicos del SFP son tan grandes que se pone difícil analizarlos. Para remediar eso los cargue a una herramien…', '_id': ObjectId('5fcd6987494e7827cd00c4c7')}
# {'created_at': 'Sun Dec 06 23:30:10 +0000 2020', 'id_str': '1335728270214483968', 'text': "RT @gazcon: @LBC @NIAbbot I'd need to be persuaded that a) Covid poses me a significant threat and b) the vaccine poses me no threat.\n\nRigh…", '_id': ObjectId('5fcd6988494e7827cd00c4c8')}
# {'created_at': 'Sun Dec 06 23:30:13 +0000 2020', 'id_str': '1335728279756677120', 'text': 'RT @epigwhisp: Everyone needs 2 see this! You thought I was kidding? The social engineering technocrats view you as cattle they want to pat…', '_id': ObjectId('5fcd698a494e7827cd00c4c9')}
# {'created_at': 'Sun Dec 06 23:30:13 +0000 2020', 'id_str': '1335728281283387392', 'text': 'RT @realpython: 🐍📰 How to Run Your Python Scripts \n\nThis step-by-step tutorial will guide you through a series of ways to run Python script…', '_id': ObjectId('5fcd698a494e7827cd00c4ca')}
# {'created_at': 'Sun Dec 06 23:30:14 +0000 2020', 'id_str': '1335728287272865793', 'text': '@Marty_cee @ByronHsu2 @DHSCgovuk @UKGovScotland @UKGovWales @healthdpt @PHE_uk @scotgovhealth @publichealthni… https://t.co/kXWoC3H1Zd', '_id': ObjectId('5fcd698c494e7827cd00c4cb')}
# {'created_at': 'Sun Dec 06 23:30:16 +0000 2020', 'id_str': '1335728293518127112', 'text': 'RT @jenstirrup: Tech Leaders news: Big data trends: Artificial intelligence leads Twitter mentions in November 2020 https://t.co/NEmCzyjO48…', '_id': ObjectId('5fcd698d494e7827cd00c4cc')}
# {'created_at': 'Sun Dec 06 23:30:18 +0000 2020', 'id_str': '1335728301680160769', 'text': 'RT @h_okumura: Zipファイルクラックの実験: Mac mini (2018) 3.6 GHz Core i3 では 534 ms，M1 MacBook Air で Rosetta 環境では 319 ms，ネイティブでは 191 ms https://t.co/4…', '_id': ObjectId('5fcd698f494e7827cd00c4cd')}
# {'created_at': 'Sun Dec 06 23:30:26 +0000 2020', 'id_str': '1335728335624630272', 'text': 'RT @odashi_t: 深層学習の入門にPRML推薦するのはPython書きたい人間にx86推薦するのと同じやな', '_id': ObjectId('5fcd6997494e7827cd00c4ce')}
# {'created_at': 'Sun Dec 06 23:30:28 +0000 2020', 'id_str': '1335728342612504581', 'text': 'Why Python for AI?\n#100DaysOfCode\n#ArtificialIntelligence\n#Python https://t.co/rYmwChpNia', '_id': ObjectId('5fcd6999494e7827cd00c4cf')}
# {'created_at': 'Sun Dec 06 23:30:31 +0000 2020', 'id_str': '1335728355816181760', 'text': 'RT @allentien: https://t.co/vhSdqMBMq7\n\n#Science\n#HumanReasoning\n\n#SharedFacts', '_id': ObjectId('5fcd699c494e7827cd00c4d0')}
# {'created_at': 'Sun Dec 06 23:30:31 +0000 2020', 'id_str': '1335728355841355777', 'text': 'RT @realpython: In order to help @ThePSF meet its end-of-year fundraising goal, we are discounting a number of our products, of which, up t…', '_id': ObjectId('5fcd699c494e7827cd00c4d1')}
# {'created_at': 'Sun Dec 06 23:30:33 +0000 2020', 'id_str': '1335728364968157186', 'text': 'RT @iamorokgospel: Why Python for AI?\n#100DaysOfCode\n#ArtificialIntelligence\n#Python https://t.co/rYmwChpNia', '_id': ObjectId('5fcd699e494e7827cd00c4d2')}
# {'created_at': 'Sun Dec 06 23:30:33 +0000 2020', 'id_str': '1335728365647482882', 'text': '@GregorYoung @EmilyLazatin "..Whipe out entire populations"\nReally? Sweden and Florida hasn\'t been wiped out. \nAnd… https://t.co/HGfmEHORMO', '_id': ObjectId('5fcd699e494e7827cd00c4d3')}
# {'created_at': 'Sun Dec 06 23:30:34 +0000 2020', 'id_str': '1335728369514778625', 'text': 'RT @GaladrielResist: @JSKIMMEL28 A discovery site that shows how disinformation works and displays of how the use of data is manipulated to…', '_id': ObjectId('5fcd699f494e7827cd00c4d4')}
# {'created_at': 'Sun Dec 06 23:30:35 +0000 2020', 'id_str': '1335728374187175941', 'text': "RT @CarrollQuigley1: This looks like a pretty big development. Maricopa County elections are notoriously shady. \n\nLet's find out if Adrian…", '_id': ObjectId('5fcd69a0494e7827cd00c4d5')}
# {'created_at': 'Sun Dec 06 23:30:38 +0000 2020', 'id_str': '1335728385948082178', 'text': 'RT @iamorokgospel: Why Python for AI?\n#100DaysOfCode\n#ArtificialIntelligence\n#Python https://t.co/rYmwChpNia', '_id': ObjectId('5fcd69a3494e7827cd00c4d6')}
# {'created_at': 'Sun Dec 06 23:30:38 +0000 2020', 'id_str': '1335728386681946113', 'text': "RT @SourabhSKatoch: Programmer deleting a seemingly unused piece of code. What's the worst that could happen?\n\n#DEVCommunity #Machinelearni…", '_id': ObjectId('5fcd69a3494e7827cd00c4d7')}
# {'created_at': 'Sun Dec 06 23:30:38 +0000 2020', 'id_str': '1335728387977953282', 'text': '#Bot\n#대리과제\n#컴공과제\n#과제 \n#프로그래밍\n프로그래밍과제 해드립니다.\n저렴한 가격에 해드리니 많은 이용 부탁드립니다!\n자세한 문의는 디엠주세요!\n주력은 알고리즘이고,\n언어는 python,c 가능합니다', '_id': ObjectId('5fcd69a4494e7827cd00c4d8')}
# {'created_at': 'Sun Dec 06 23:30:42 +0000 2020', 'id_str': '1335728403207622664', 'text': '@segfaultvicta ^_^ I like it because it reminds me syntactically a lot of Python, but with much stricter rules type… https://t.co/neawc6Ee61', '_id': ObjectId('5fcd69a7494e7827cd00c4d9')}
# {'created_at': 'Sun Dec 06 23:30:42 +0000 2020', 'id_str': '1335728403668996099', 'text': "Don't miss your deadline!! \n#Essay due\n#Pay write\n#javascript\n#Online class take\n#Philosophy \n#Chemistry… https://t.co/7RuXjHoyj4", '_id': ObjectId('5fcd69a7494e7827cd00c4da')}
# {'created_at': 'Sun Dec 06 23:30:44 +0000 2020', 'id_str': '1335728409754783744', 'text': "RT @SourabhSKatoch: Programmer deleting a seemingly unused piece of code. What's the worst that could happen?\n\n#DEVCommunity #Machinelearni…", '_id': ObjectId('5fcd69a9494e7827cd00c4db')}
# {'created_at': 'Sun Dec 06 23:30:44 +0000 2020', 'id_str': '1335728410929328132', 'text': 'RT @iamorokgospel: Why Python for AI?\n#100DaysOfCode\n#ArtificialIntelligence\n#Python https://t.co/rYmwChpNia', '_id': ObjectId('5fcd69a9494e7827cd00c4dc')}
# {'created_at': 'Sun Dec 06 23:30:47 +0000 2020', 'id_str': '1335728425517125633', 'text': "RT @MathsChemistry: Don't miss your deadline!! \n#Essay due\n#Pay write\n#javascript\n#Online class take\n#Philosophy \n#Chemistry\n#Literature\n#C…", '_id': ObjectId('5fcd69ad494e7827cd00c4dd')}
# {'created_at': 'Sun Dec 06 23:30:48 +0000 2020', 'id_str': '1335728426708328449', 'text': 'RT @SSNaushon: @ashishkjha @CharlieBakerMA Always a strong supporter of Gov.Baker. Impressed in Spring with his grasp of situation and emph…', '_id': ObjectId('5fcd69ad494e7827cd00c4de')}
# {'created_at': 'Sun Dec 06 23:30:48 +0000 2020', 'id_str': '1335728426905268225', 'text': "RT @MathsChemistry: Don't miss your deadline!! \n#Essay due\n#Pay write\n#javascript\n#Online class take\n#Philosophy \n#Chemistry\n#Literature\n#C…", '_id': ObjectId('5fcd69ad494e7827cd00c4df')}
# {'created_at': 'Sun Dec 06 23:30:50 +0000 2020', 'id_str': '1335728434484563968', 'text': 'Python for Machine Learning and Data Mining https://t.co/aBizheXslP  #DataMining #MachineLearning', '_id': ObjectId('5fcd69af494e7827cd00c4e0')}
# {'created_at': 'Sun Dec 06 23:30:53 +0000 2020', 'id_str': '1335728449575669761', 'text': 'RT @Udemy_Coupons1: App promotional Video in Adobe After Effects | 100%OFF Coupon https://t.co/ZEoJpyOAOm\n\n#MachineLearning #BigData #Analy…', '_id': ObjectId('5fcd69b2494e7827cd00c4e1')}
# {'created_at': 'Sun Dec 06 23:30:55 +0000 2020', 'id_str': '1335728456546586632', 'text': 'RT @machinelearnflx: Python for Machine Learning and Data Mining https://t.co/aBizheXslP  #DataMining #MachineLearning', '_id': ObjectId('5fcd69b4494e7827cd00c4e2')}
# {'created_at': 'Sun Dec 06 23:30:56 +0000 2020', 'id_str': '1335728461508329472', 'text': 'RT @charliekirk11: Every Republican should oppose S.386/H.R.1044 - which is a big tech/big data immigration handout that will severely hurt…', '_id': ObjectId('5fcd69b5494e7827cd00c4e3')}
# {'created_at': 'Sun Dec 06 23:31:00 +0000 2020', 'id_str': '1335728476884783104', 'text': 'RT @iamorokgospel: Why Python for AI?\n#100DaysOfCode\n#ArtificialIntelligence\n#Python https://t.co/rYmwChpNia', '_id': ObjectId('5fcd69b9494e7827cd00c4e4')}
# {'created_at': 'Sun Dec 06 23:31:02 +0000 2020', 'id_str': '1335728487869546497', 'text': 'RT @DeAngelisCorey: @CTULocal1 Dr. Fauci: "The default position should be to try as best as possible within reason to keep the children in…', '_id': ObjectId('5fcd69bb494e7827cd00c4e5')}
# {'created_at': 'Sun Dec 06 23:31:03 +0000 2020', 'id_str': '1335728491397079040', 'text': 'RT @BootlegGirl: @segfaultvicta ^_^ I like it because it reminds me syntactically a lot of Python, but with much stricter rules types, but…', '_id': ObjectId('5fcd69bc494e7827cd00c4e6')}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-6a9070444200> in <module>
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:

# %% [markdown]
# ## --> Pressione o botão Stop na barra de ferramentas para encerrar a captura dos Tweets

# %% [markdown]
# ## Consultando os Dados no MongoDB

# %%
mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5fcd6950494e7827cd00c4ae'),
#  'created_at': 'Sun Dec 06 23:29:14 +0000 2020',
#  'id_str': '1335728035245432834',
#  'text': 'github 上で最も多く使われているのは javascript。次点で python。typescript の伸びがすごい。 / “The State of the Octoverse | The State of the Oc… https://t.co/YyWoVqno8R'}

# %% [markdown]
# ## Análise de Dados com Pandas e Scikit-Learn

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd
pd.__version__
# Out:
# '1.0.1'

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                         created_at  \
# 0   Sun Dec 06 23:29:14 +0000 2020
# 1   Sun Dec 06 23:29:20 +0000 2020
# 2   Sun Dec 06 23:29:23 +0000 2020
# 3   Sun Dec 06 23:29:27 +0000 2020
# 4   Sun Dec 06 23:29:29 +0000 2020
# 5   Sun Dec 06 23:29:34 +0000 2020
# 6   Sun Dec 06 23:29:46 +0000 2020
# 7   Sun Dec 06 23:29:46 +0000 2020
# 8   Sun Dec 06 23:29:50 +0000 2020
# 9   Sun Dec 06 23:29:51 +0000 2020
# 10  Sun Dec 06 23:29:53 +0000 2020
# 11  Sun Dec 06 23:29:54 +0000 2020
# 12  Sun Dec 06 23:29:55 +0000 2020
# 13  Sun Dec 06 23:30:00 +0000 2020
# 14  Sun Dec 06 23:30:00 +0000 2020
# 15  Sun Dec 06 23:30:00 +0000 2020
# 16  Sun Dec 06 23:30:02 +0000 2020
# 17  Sun Dec 06 23:30:02 +0000 2020
# 18  Sun Dec 06 23:30:03 +0000 2020
# 19  Sun Dec 06 23:30:03 +0000 2020
# 20  Sun Dec 06 23:30:06 +0000 2020
# 21  Sun Dec 06 23:30:06 +0000 2020
# 22  Sun Dec 06 23:30:07 +0000 2020
# 23  Sun Dec 06 23:30:08 +0000 2020
# 24  Sun Dec 06 23:30:08 +0000 2020
# 25  Sun Dec 06 23:30:10 +0000 2020
# 26  Sun Dec 06 23:30:10 +0000 2020
# 27  Sun Dec 06 23:30:13 +0000 2020
# 28  Sun Dec 06 23:30:13 +0000 2020
# 29  Sun Dec 06 23:30:14 +0000 2020
# 30  Sun Dec 06 23:30:16 +0000 2020
# 31  Sun Dec 06 23:30:18 +0000 2020
# 32  Sun Dec 06 23:30:26 +0000 2020
# 33  Sun Dec 06 23:30:28 +0000 2020
# 34  Sun Dec 06 23:30:31 +0000 2020
# 35  Sun Dec 06 23:30:31 +0000 2020
# 36  Sun Dec 06 23:30:33 +0000 2020
# 37  Sun Dec 06 23:30:33 +0000 2020
# 38  Sun Dec 06 23:30:34 +0000 2020
# 39  Sun Dec 06 23:30:35 +0000 2020
# 40  Sun Dec 06 23:30:38 +0000 2020
# 41  Sun Dec 06 23:30:38 +0000 2020
# 42  Sun Dec 06 23:30:38 +0000 2020
# 43  Sun Dec 06 23:30:42 +0000 2020
# 44  Sun Dec 06 23:30:42 +0000 2020
# 45  Sun Dec 06 23:30:44 +0000 2020
# 46  Sun Dec 06 23:30:44 +0000 2020
# 47  Sun Dec 06 23:30:47 +0000 2020
# 48  Sun Dec 06 23:30:48 +0000 2020
# 49  Sun Dec 06 23:30:48 +0000 2020
# 50  Sun Dec 06 23:30:50 +0000 2020
# 51  Sun Dec 06 23:30:53 +0000 2020
# 52  Sun Dec 06 23:30:55 +0000 2020
# 53  Sun Dec 06 23:30:56 +0000 2020
# 54  Sun Dec 06 23:31:00 +0000 2020
# 55  Sun Dec 06 23:31:02 +0000 2020
# 56  Sun Dec 06 23:31:03 +0000 2020
#
#                                                  text
# 0   github 上で最も多く使われているのは javascript。次点で python。ty...
# 1   RT @hnishi2509: github 上で最も多く使われているのは javascri...
# 2   Big changes to QRIScloud are afoot, with agein...
# 3   Historically the racialised disproportionate e...
# 4   RT @StackCodeReview: Hackerrank: Count the num...
# 5   RT @MeowTPN: Historically the racialised dispr...
# 6   RT @CroatiaC: Top story: Big data trends: Arti...
# 7   @lipsaraiva @pizzaiolom @PizzaiolomX @D1oRod N...
# 8   RT @JanJekielek: Communist #China "used artifi...
# 9   RT @carlcarrie: TsEuler - Holoviews Panel base...
# 10  RT @karynbaum: empathy=weakness\n"freedom"=rig...
# 11  RT @PGtzsche1: Covid-19 vaccines: Science by p...
# 12  RT @IWasHrren: Pennsylvania Dems predict\nAT L...
# 13  #InPics | December 4, 1971: How Indian Navy's ...
# 14  🐍📰 How to Run Your Python Scripts \n\nThis ste...
# 15  Kubernetes:What You Need To Know \nhttps://t.c...
# 16  buildreeを使えば開発に専念できます\n https://t.co/ucQNXnOUm...
# 17  The first purchase on Amazon was by a Bay Area...
# 18  RT @gazcon: @LBC @NIAbbot I'd need to be persu...
# 19  New upload: python-build 0.1.0-2 by Sergio Dur...
# 20  I have a premium subscription on @MeWe now, bu...
# 21  RT @DetlefBurkhardt: My week 49 on Twitter: 67...
# 22  RT @y__hayashi: buildreeを使えば開発に専念できます\n https:...
# 23             I can’t add anything valuable to this.
# 24  RT @GavLaaaaaaaa: The first purchase on Amazon...
# 25  RT @karlbooklover: Los datos públicos del SFP ...
# 26  RT @gazcon: @LBC @NIAbbot I'd need to be persu...
# 27  RT @epigwhisp: Everyone needs 2 see this! You ...
# 28  RT @realpython: 🐍📰 How to Run Your Python Scri...
# 29  @Marty_cee @ByronHsu2 @DHSCgovuk @UKGovScotlan...
# 30  RT @jenstirrup: Tech Leaders news: Big data tr...
# 31  RT @h_okumura: Zipファイルクラックの実験: Mac mini (2018)...
# 32  RT @odashi_t: 深層学習の入門にPRML推薦するのはPython書きたい人間にx...
# 33  Why Python for AI?\n#100DaysOfCode\n#Artificia...
# 34  RT @allentien: https://t.co/vhSdqMBMq7\n\n#Sci...
# 35  RT @realpython: In order to help @ThePSF meet ...
# 36  RT @iamorokgospel: Why Python for AI?\n#100Day...
# 37  @GregorYoung @EmilyLazatin "..Whipe out entire...
# 38  RT @GaladrielResist: @JSKIMMEL28 A discovery s...
# 39  RT @CarrollQuigley1: This looks like a pretty ...
# 40  RT @iamorokgospel: Why Python for AI?\n#100Day...
# 41  RT @SourabhSKatoch: Programmer deleting a seem...
# 42  #Bot\n#대리과제\n#컴공과제\n#과제 \n#프로그래밍\n프로그래밍과제 해드립니...
# 43  @segfaultvicta ^_^ I like it because it remind...
# 44  Don't miss your deadline!! \n#Essay due\n#Pay ...
# 45  RT @SourabhSKatoch: Programmer deleting a seem...
# 46  RT @iamorokgospel: Why Python for AI?\n#100Day...
# 47  RT @MathsChemistry: Don't miss your deadline!!...
# 48  RT @SSNaushon: @ashishkjha @CharlieBakerMA Alw...
# 49  RT @MathsChemistry: Don't miss your deadline!!...
# 50  Python for Machine Learning and Data Mining ht...
# 51  RT @Udemy_Coupons1: App promotional Video in A...
# 52  RT @machinelearnflx: Python for Machine Learni...
# 53  RT @charliekirk11: Every Republican should opp...
# 54  RT @iamorokgospel: Why Python for AI?\n#100Day...
# 55  RT @DeAngelisCorey: @CTULocal1 Dr. Fauci: "The...
# 56  RT @BootlegGirl: @segfaultvicta ^_^ I like it ...

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
import sklearn
sklearn.__version__
# Out:
# '0.22.1'

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                       word  count
# 0                       rt     38
# 1                       co     34
# 2                    https     34
# 3                   python     26
# 4                      the     26
# 5                       to     21
# 6                       of     21
# 7                       in     13
# 8                      and     13
# 9                      for      8
# 10                    data      8
# 11                     big      7
# 12                      it      7
# 13                    your      7
# 14                      by      7
# 15                    with      7
# 16                     you      7
# 17                      me      6
# 18                     how      6
# 19                    that      6
# 20                      on      5
# 21                    this      5
# 22              javascript      5
# 23                      be      5
# 24                      ai      5
# 25                     why      5
# 26              rymwchpnia      5
# 27                     was      5
# 28           100daysofcode      5
# 29  artificialintelligence      5
# 30              programmer      4
# 31                   poses      4
# 32                   state      4
# 33                    step      4
# 34                      as      4
# 35                  threat      4
# 36                     run      4
# 37                     but      4
# 38                     out      4
# 39           iamorokgospel      4
# 40               octoverse      3
# 41               chemistry      3
# 42                    take      3
# 43         machinelearning      3
# 44                    will      3
# 45                   essay      3
# 46                    been      3
# 47              philosophy      3
# 48                  online      3
# 49                    what      3

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
